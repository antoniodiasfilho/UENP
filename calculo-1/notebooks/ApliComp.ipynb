# %% [markdown]
# Funções

# %%
from sympy import symbols, Lambda, sin, cos

# %%
x = symbols("x")
y = symbols("y")
f = Lambda(x, x**2 + 3)
f

# %%
f(1)

# %%
f(sin(y))

# %%
a,h = symbols("a,h")
g = Lambda(x,x**2 + 2*x + 3)
g

# %%
g(a+h)

# %%
g(a)

# %%
g(a+h) - g(a)

# %%
s,t,u = symbols("s,t,u")
h = Lambda((s, t, u), s*t+u)
h

# %%
from sympy import expand

# %%
i = symbols("i")
i = Lambda(x,x*(x*(sin(x) + 2) + x))
i

# %%
i.expand(deep = False)

# %%
i.expand(deep = True)

# %%
j = symbols("j")
a,h = symbols("a,h")
j = Lambda((a,h),(a + h)**2)
j

# %%
j.expand(deep = False)

# %%
j.expand(deep = True)

# %%
from sympy import collect, Rational, factor

# %%
alpha, beta = symbols("alpha, beta")
expr = alpha * beta + alpha + 1
expr

# %%
r = expr.collect(alpha)
r

# %%
m = Lambda(x,x**2+3*x + 1)
m

# %%
q = m.collect(x)
q

# %%
E, L = symbols("E,L", real = True, positive = True)
rho, p, pi, sigma = symbols("rho,p,pi,sigma", real=True,positive=True)
Vs, Ms = symbols("V,M", real = True, positive = True)

# %%
V = pi * (E/2) ** 2 * L + Rational(4,3) * pi * (E/2) ** 3
M = pi * E ** 2 * rho * p / (2* sigma) * (L + E / 2)
display(V,M)

# %%
V.factor()

# %%
V.factor() / E**3

# %% [markdown]
# Numerador e Denominador

# %%
x = symbols("x")
expr1 = (x**2+1) / x
expr1

# %%
from sympy import fraction, numer,denom

# %%
num, den = fraction(expr1)
display(num,den)

# %%
num = numer(expr1)
den = denom(expr1)
display(num,den)

# %% [markdown]
# Tipos de Numeros

# %%
a = 2
b = 2.0
c = 2/3
type(a), type(b), type(c)

# %%
expr1 = x + 2
expr2 = x + 2.0
expr3 = x + 2/3

expr1, expr2, expr3

# %%
expr = x + Rational(2,3)
expr

# %%
from sympy import solve, solveset, symbols, Symbol, sin, Eq, Abs, Reals, FiniteSet, cos, Intersection

# %%
p, V, R, T = symbols("p, V, R, T")

eq = p * V - R*T

s1 = solve(eq, T)

s2 = solveset(eq, T)

display(eq, s1, s2)

# %%
print(type(s2))

# %%
print(type(s1))

# %%
x = Symbol("x")

eq = Eq(sin(x),1)

s1 = solve(eq)

s2 = solveset(eq)

display(eq,s1,s2)

# %%
print(s2.func)
s2.args

# %%
s2.lamda(1)

# %%
x = Symbol("x",real = True)

eq = Eq(Abs(sin(x)),1)

s1 = solve(eq)

display(eq, s1)

# %%
i = sin(x) + cos(x) >= 0

s1 = solve(i,x)

s2 = solveset(i,x, domain = Reals)

display(i, s1, s2)

# %%
from sympy import sqrt

# %%
i2 = Abs(sqrt((Rational(1/2)- x) * (x-3))) <= 1
i2
