# %%
from sympy import symbols, Lambda, sin, cos

# %%
x = symbols("x")
f = Lambda(x, (x - 1) / (x ** 2 - 1))
f

# %%
f(0)

# %%
f(0.6)

# %%
f(0.7)

# %%
f(1)

# %%
from pylab import *

# %%
def calcula_f(x):
  return (x-1)/(x**2-1)

# %%
x = arange(0.1,2,0.01)

# %%
y = calcula_f(x)

# %%
plot(x,y)
xlabel('Variavel Independente')
ylabel('Função y = (x-1)/(x^2 - 1)')
title('Visão Geometrica do conceito de Limite')
grid(True)
axis([-1,2,0,1])
axhline(y=0, color = 'k')
axvline(x=0, color = 'k')

# %%
from math import sqrt, pow
t = symbols("t")
g = Lambda(t, (((t**2 + 9)**0.5) - 3) / t**2)
g

# %%
def calcula_f(t):
  return (((t**2 + 9)**0.5) - 3) / t**2

# %%
t = arange(0.1,2,0.01)

# %%
y = calcula_f(t)

# %%
plot(x,y)
xlabel('Variavel Independente')
ylabel('Função y = (((t**2 + 9)**0.5) - 3) / t**2)')
title('Visão Geometrica do conceito de Limite')
grid(True)
axis([-1,2,0,1])
axhline(y=0, color = 'k')
axvline(x=0, color = 'k')

# %%
from math import *
from sympy import *
x = symbols("x")
y = Lambda(x, (sin(pi/x)))
y
